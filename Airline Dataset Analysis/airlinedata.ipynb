# %% [markdown]
# # Airline Flight Dat Analysis

# %% [markdown]
# Project: Analysis of Airline Dataset using NumPy, Pandas, and Matplotlib Problem Statement: You are working for an airline company that wants to analyze its passenger data for the past year. The company has provided you with a CSV file containing the monthly passenger data for each airline

# %% [markdown]
# ### Import required Libraries

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the Dataset

# %%
# Load dataset of flights
df = pd.read_csv('flights.csv')

# %% [markdown]
# ### Preprocess the data

# %%
# Show first 5 rows
df.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
# Check data types
df.dtypes
# Out:
# year           int64
# month         object
# passengers     int64
# dtype: object

# %%
# Check missing values
df.isnull().sum()
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %%
# Check duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Question No.1) What is the trend of monthly passenger traffic for each airline? Plot the line graph to show the same.

# %%
# Create a pivot table with months as the index and years as columns
# The 'values' parameter specifies that we want to aggregate the 'passengers' column
# 'index' specifies that months should be the rows, 'columns' specifies years should be columns
passenger_traffic = df.pivot_table(values='passengers', index='month', columns='year')

passenger_traffic.plot(figsize=(10, 8))

plt.xlabel('Month')

plt.ylabel('Passenger Traffic')

plt.title('Monthly Passenger Traffic Trend for Each Airline')

plt.show()

# %% [markdown]
# The above graph shows that the trend of monthly passenger traffic for each airline is increasing.

# %% [markdown]
# Question No.2) What is the overall monthly passenger traffic trend for all airlines combined? Plot the line graph to show the same.

# %%
# Sum the passenger traffic across all airlines for each month
df['Total_Passengers'] = df.groupby('month')['passengers'].transform('sum')

# Remove duplicate rows since we only need one row per month
overall_trend = df[['month', 'Total_Passengers']].drop_duplicates().set_index('month')

# %%
# Plot the overall monthly passenger traffic trend
plt.figure(figsize=(10, 6))
plt.plot(overall_trend.index, overall_trend['Total_Passengers'], marker='o', color='green')

plt.title('Overall Monthly Passenger Traffic Trend (All Airlines Combined)')
plt.xlabel('Month')
plt.ylabel('Total Number of Passengers')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# this graph shows that the trend of monthly passenger traffic for all airlines is increasing.
